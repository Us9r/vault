# %% [markdown]
# <a href="https://colab.research.google.com/github/Us9r/vault/blob/main/scraping/youtube_comments_advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dev = "AIzaSyAm1U1j0_fQ1AmbN4JPkiHQXmve9ET92XA"

# %% [markdown]
# ## Pull All Comments

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="BHkTABfl9fc",
    maxResults=12370
)

comments = []

# Execute the request.
response = request.execute()

# Get the comments from the response.
for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

while (1 == 1):
  try:
   nextPageToken = response['nextPageToken']
  except KeyError:
   break
  nextPageToken = response['nextPageToken']
  # Create a new request object with the next page token.
  nextRequest = youtube.commentThreads().list(part="snippet", videoId="BHkTABfl9fc", maxResults=12370, pageToken=nextPageToken)
  # Execute the next request.
  response = nextRequest.execute()
  # Get the comments from the next response.
  for item in response['items']:
    comment = item['snippet']['topLevelComment']['snippet']
    public = item['snippet']['isPublic']
    comments.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['likeCount'],
        comment['textOriginal'],
        public
    ])

df = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','public'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9059 entries, 0 to 9058
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   author      9059 non-null   object
#  1   updated_at  9059 non-null   object
#  2   like_count  9059 non-null   int64
#  3   text        9059 non-null   object
#  4   public      9059 non-null   bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 292.1+ KB

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': 'I5XfdkXheT2JYkJi4VyP3dsACxw',
#  'id': 'Ugy3XLc5NBHSwWv7isN4AaABAg',
#  'snippet': {'channelId': 'UC1dI4tO13ApuSX0QeX8pHng',
#   'videoId': 'BHkTABfl9fc',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'pJH4mwQbD0IDK8nxx70oYDOYJ5k',
#    'id': 'Ugy3XLc5NBHSwWv7isN4AaABAg',
#    'snippet': {'channelId': 'UC1dI4tO13ApuSX0QeX8pHng',
#     'videoId': 'BHkTABfl9fc',
#     'textDisplay': 'Elon pasti senang melihat ini',
#     'textOriginal': 'Elon pasti senang melihat ini',
#     'authorDisplayName': '@rezkex',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/j7kuGco_PbMoPUNtJSpEM_IaFM6MikYNVxdGHcYMCVgTLoNNmGDWkaIVV5Vwv71V2gf_XyfUBA=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@rezkex',
#     'authorChannelId': {'value': 'UClyIpBKGA5cZ-7TV8FA8F7A'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 1,
#     'publishedAt': '2024-05-22T10:03:17Z',
# ...

# %%
df.head(10)
# Out:
#                 author            updated_at  like_count  \
# 0        @AdriantDrian  2024-12-06T03:18:51Z           0
# 1      @saddestboy2966  2024-12-05T04:43:30Z           0
# 2          @Dion-ry8td  2024-12-03T21:39:58Z           0
# 3        @tomotomo4066  2024-12-03T06:45:53Z           0
# 4          @nicocs3316  2024-12-02T15:26:40Z           0
# 5           @Hobiuthek  2024-12-01T16:15:17Z           0
# 6  @VictorPaulus-wv5gm  2024-12-01T09:05:33Z           0
# 7  @DewiSahputri-fe8uv  2024-12-01T06:31:03Z           0
# 8         @ChiaraGitta  2024-11-28T20:31:53Z           1
# 9          @Dafi-up3jq  2024-11-28T14:32:31Z           0
#
#                                                 text  public
# 0  Bus Bus Lintas Sumatera Jawa Kalimantan sudah ...    True
# 1         rekomendasi power bank untuk starlink dong    True
# 2                                        lanjut bang    True
# 3  Saya pengin beli tapi mau saya jual lagi. Kala...    True
# ...

# %% [markdown]
# ## Sort by Likes and Get Top 10

# %%
df.sort_values(by='like_count', ascending=False)[0:10]
# Out:
#                            author            updated_at  like_count  \
# 8423                   @NanangMrk  2024-05-22T10:49:20Z       15406
# 9038          @asrirafifahmad7903  2024-05-22T10:02:09Z        7372
# 8199      @a.fikrinailularzaq4105  2024-05-22T11:09:34Z        5282
# 8952                   @irfanzizi  2024-05-22T10:05:44Z        1376
# 6057            @adiadisecond8971  2024-05-22T17:14:30Z        1268
# 8685            @fajarcahyono3693  2024-05-22T10:30:48Z         936
# 3251                  @driman5281  2024-05-24T00:29:25Z         557
# 3536                 @aiyulee6366  2024-05-23T14:39:44Z         526
# 8887  @mochammadariqatillah2000an  2024-05-22T10:10:43Z         478
# 4955                @yapghazz7862  2024-05-23T03:33:50Z         365
#
#                                                    text  public
# 8423  Prestasi tertinggi politisi : dipanggil close ...    True
# 9038                                 Starbucks keliling    True
# ...

# %%
# prompt: export df ke file csv

# Export the DataFrame to a CSV file
df.to_csv('comments_data.csv', index=False)  # index=False prevents writing row indices

# To download the file to your local machine
from google.colab import files
files.download('comments_data.csv')

# %% [markdown]
# #Pull all Comments for Multiple Videos

# %% [markdown]
# ## 1. Get Comments Function

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = dev

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)


def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'updated_at', 'like_count', 'text','video_id','public'])
  return df2

# %%
df = getcomments('TYxqBTdOq24')
df
# Out:
#                 author            updated_at  like_count  \
# 0               yaohun  2023-09-08T05:43:51Z           0
# 1       Cedric Goodwin  2023-06-08T07:21:41Z           0
# 2  Analytics with Adam  2023-05-10T06:12:50Z           1
#
#                                                 text     video_id  public
# 0  Hi, sorry I am very new to SAP dashboard and h...  TYxqBTdOq24    True
# 1                                         ⭐ Promo_SM  TYxqBTdOq24    True
# 2  Interested in thoughts on SAC compared with Po...  TYxqBTdOq24    True

# %% [markdown]
# ## 2. For Loop for List of IDs

# %%
df = pd.DataFrame()
for i in ['QOcP5OvSwlI','Lfzu74XDyco','TiS6vnju_mI','cYwioeHu_OU']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df
# Out:
#                  author            updated_at  like_count  \
# 0        Artur Nawrocki  2023-10-27T06:28:00Z           0
# 1        Bostjan Brumec  2023-10-27T06:23:00Z           0
# 2       Esteban Herrera  2023-10-27T04:12:19Z           0
# 3                Jyothi  2023-10-27T02:07:35Z           0
# 4            Anil Ameer  2023-10-26T19:42:54Z           0
# ..                  ...                   ...         ...
# 440  sameer vishwakarma  2022-06-30T11:17:57Z           0
# 441       Adam Sikorski  2022-06-30T11:13:33Z           0
# 442  Unq.Universalfacts  2022-06-30T11:09:16Z           0
# 443         Ahmed Tareq  2022-06-30T11:04:25Z           0
# 444     Jonathan CHANAL  2022-06-30T11:03:35Z           0
#
#                                                   text     video_id  public
# 0    SVG visuals has taken LinkedIn by storm. Too l...  QOcP5OvSwlI    True
# 1    Very inspiring! Maybe it can be used to create...  QOcP5OvSwlI    True
# ...

# %%
df['video_id'].value_counts()
# Out:
# cYwioeHu_OU    445
# Lfzu74XDyco    371
# TiS6vnju_mI    100
# QOcP5OvSwlI     50
# Name: video_id, dtype: int64
